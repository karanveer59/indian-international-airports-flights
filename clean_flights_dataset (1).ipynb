# %%
print("Jai Hanuman🙏🙏🙏🙏🙏")
# Out:
# Jai Hanuman🙏🙏🙏🙏🙏

# %%
import pandas as pd
import numpy as np
import plotly as plt
import seaborn as sas

# %%
df = pd.read_csv('file2.csv')

# %%
tempdf = df.copy()
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29606 entries, 0 to 29605
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         29606 non-null  object
#  1   Airline_Code    29606 non-null  object
#  2   Flight_Number   29606 non-null  int64
#  3   Cabin_Class     29606 non-null  object
#  4   Aircraft_Type   29606 non-null  object
#  5   Departure_Time  29606 non-null  object
#  6   Departure_Port  29606 non-null  object
#  7   Arrival_Time    29606 non-null  object
#  8   Arrival_Port    29606 non-null  object
#  9   Duration        29606 non-null  object
#  10  Stop            29606 non-null  object
#  11  Fare            29606 non-null  object
#  12  Meal            19232 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.9+ MB

# %%
tempdf['Departure_Time'] = pd.to_datetime(tempdf['Departure_Time'],errors='coerce')
# Out:
# /tmp/ipython-input-45-2300031687.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   tempdf['Departure_Time'] = pd.to_datetime(tempdf['Departure_Time'],errors='coerce')

# %%
tempdf[tempdf['Departure_Time'].isnull()]
# tempdf.info()
# Out:
#      Airline Airline_Code  Flight_Number Cabin_Class Aircraft_Type  \
# 4202  IndiGo           6E            257     ECONOMY   Airbus A320
#
#      Departure_Time Departure_Port Arrival_Time Arrival_Port Duration  \
# 4202            NaT         Bhopal        04:30         Pune  01h 30m
#
#           Stop   Fare Meal
# 4202  Non-stop  4,049  NaN

# %%
tempdf[tempdf['Departure_Time'].isnull()]
# Out:
#      Airline Airline_Code  Flight_Number Cabin_Class Aircraft_Type  \
# 4202  IndiGo           6E            257     ECONOMY   Airbus A320
#
#      Departure_Time Departure_Port Arrival_Time Arrival_Port Duration  \
# 4202            NaT         Bhopal        04:30         Pune  01h 30m
#
#           Stop   Fare Meal
# 4202  Non-stop  4,049  NaN

# %%
tempdf = tempdf.dropna(subset=['Departure_Time'])

# %%
tempdf['Arrival_Time'] = pd.to_datetime(tempdf['Arrival_Time'])
# Out:
# /tmp/ipython-input-50-335259252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   tempdf['Arrival_Time'] = pd.to_datetime(tempdf['Arrival_Time'])

# %%
tempdf[tempdf['Arrival_Time'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Airline_Code, Flight_Number, Cabin_Class, Aircraft_Type, Departure_Time, Departure_Port, Arrival_Time, Arrival_Port, Duration, Stop, Fare, Meal]
# Index: []

# %%
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29605 entries, 0 to 29605
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         29605 non-null  object
#  1   Airline_Code    29605 non-null  object
#  2   Flight_Number   29605 non-null  int64
#  3   Cabin_Class     29605 non-null  object
#  4   Aircraft_Type   29605 non-null  object
#  5   Departure_Time  29605 non-null  datetime64[ns]
#  6   Departure_Port  29605 non-null  object
#  7   Arrival_Time    29605 non-null  datetime64[ns]
#  8   Arrival_Port    29605 non-null  object
#  9   Duration        29605 non-null  object
#  10  Stop            29605 non-null  object
#  11  Fare            29605 non-null  object
#  12  Meal            19232 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(10)
# memory usage: 3.2+ MB

# %%
tempdf['Duration'] = tempdf['Duration'].str.replace('h',':').str.replace(' ','').str.replace('m','').str.rstrip(" + : .  ").str.lstrip(' : +')

# %%
tempdf['Duration'] = pd.to_timedelta(tempdf['Duration']+':00')

# %%
tempdf['Fare'] = tempdf['Fare'].str.replace(',','').astype('int64')

# %%
tempdf['Cabin_Class'] = tempdf['Cabin_Class'].astype('category')

# %%
tempdf['Airline'] = tempdf['Airline'].astype('category')

# %%
tempdf['Stop'] = tempdf['Stop'].str.replace(r'[^0-9]','',regex=True).str.strip()

# %%
tempdf['Stop'] = tempdf['Stop'].replace('',np.nan).fillna("0")

# %%
tempdf['Stop'] = tempdf['Stop'].astype('int8')

# %%
tempdf.Meal = tempdf.Meal.replace(np.nan,'No').replace('Enjoy Free Meals',"Yes")

# %%
tempdf.rename(columns={'Meal':'Enjoy Free Meals'},inplace=True)

# %%
tempdf['Enjoy Free Meals'] = tempdf['Enjoy Free Meals'].astype('category')

# %%
tempdf.sample(2)
# Out:
#          Airline Airline_Code  Flight_Number Cabin_Class Aircraft_Type  \
# 25003     IndiGo           6E           6764     ECONOMY   Airbus A321
# 19974  Air India           AI           9719    BUSINESS    Boeing 737
#
#            Departure_Time Departure_Port        Arrival_Time Arrival_Port  \
# 25003 2025-07-05 14:35:00       Agartala 2025-07-05 15:30:00     Guwahati
# 19974 2025-07-05 18:40:00         Jaipur 2025-07-05 15:30:00      Chennai
#
#              Duration  Stop   Fare Enjoy Free Meals
# 25003 0 days 00:55:00     0   1885               No
# 19974 0 days 20:50:00     1  42293              Yes

# %%
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29605 entries, 0 to 29605
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           29605 non-null  category
#  1   Airline_Code      29605 non-null  object
#  2   Flight_Number     29605 non-null  int64
#  3   Cabin_Class       29605 non-null  category
#  4   Aircraft_Type     29605 non-null  object
#  5   Departure_Time    29605 non-null  datetime64[ns]
#  6   Departure_Port    29605 non-null  object
#  7   Arrival_Time      29605 non-null  datetime64[ns]
#  8   Arrival_Port      29605 non-null  object
#  9   Duration          29605 non-null  timedelta64[ns]
#  10  Stop              29605 non-null  int8
#  11  Fare              29605 non-null  int64
#  12  Enjoy Free Meals  29605 non-null  category
# dtypes: category(3), datetime64[ns](2), int64(2), int8(1), object(4), timedelta64[ns](1)
# memory usage: 2.4+ MB

# %%
tempdf['Arrival_Port'] = tempdf['Arrival_Port'].apply(lambda x:x.replace('Vishakhapatnam',"Visakhapatnam"))

# %%
tempdf = tempdf.replace(['Vishakhapatnam','Tiruchirapally'],["Visakhapatnam","Tiruchirappalli"])

# %%
tempdf = tempdf[~((tempdf['Arrival_Port'] == 'Ghaziabad') | (tempdf['Departure_Port'] == 'Ghaziabad'))]
tempdf = tempdf[~((tempdf['Arrival_Port'] == 'Jalandhar') | (tempdf['Departure_Port'] == 'Jalandhar'))]

# %%
tempdf[tempdf['Departure_Port'] == 'Ghazibad']
# Out:
# Empty DataFrame
# Columns: [Airline, Airline_Code, Flight_Number, Cabin_Class, Aircraft_Type, Departure_Time, Departure_Port, Arrival_Time, Arrival_Port, Duration, Stop, Fare, Enjoy Free Meals]
# Index: []

# %%
tempdf.Arrival_Port.value_counts()

# %%
tempdf['Departure_Port'].value_counts()

# %%
tempdf = tempdf.replace('Akasa',"AkasaAir")
# Out:
# /tmp/ipython-input-72-3220466928.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   tempdf = tempdf.replace('Akasa',"AkasaAir")

# %%
tempdf.Airline.value_counts()

# %%
tempdf.Airline_Code.value_counts()

# %%
tempdf.Flight_Number.value_counts()

# %%
tempdf.Cabin_Class.value_counts()

# %%
tempdf.Aircraft_Type.value_counts()

# %%
tempdf.Stop.value_counts()

# %%
tempdf['Enjoy Free Meals'].value_counts()

# %%
tempdf.groupby(['Airline','Stop']).size()

# %%
tempdf.drop_duplicates(keep='first',inplace= True)

# %%
tempdf[['Flight_Number','Departure_Time','Departure_Port','Arrival_Time',"Arrival_Port"]]

# %%
tempdf[(tempdf.Flight_Number == 2965) & (tempdf.Departure_Time == '2025-07-05 04:15:00') & (tempdf.Departure_Port=='Goa') & (tempdf.Arrival_Time=='2025-07-05 13:00:00') & (tempdf.Arrival_Port=='Madurai')]
# Out:
# Empty DataFrame
# Columns: [Airline, Airline_Code, Flight_Number, Cabin_Class, Aircraft_Type, Departure_Time, Departure_Port, Arrival_Time, Arrival_Port, Duration, Stop, Fare, Enjoy Free Meals]
# Index: []

# %%
tempdf.drop_duplicates(subset=['Airline','Airline_Code','Flight_Number','Cabin_Class','Aircraft_Type','Departure_Time','Departure_Port','Arrival_Time','Arrival_Port','Duration','Stop','Enjoy Free Meals'], keep='first' ,inplace =True)

# %%
tempdf[tempdf[['Airline','Airline_Code','Flight_Number','Cabin_Class','Aircraft_Type','Departure_Time','Departure_Port','Arrival_Time','Arrival_Port','Duration','Stop','Enjoy Free Meals']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Airline, Airline_Code, Flight_Number, Cabin_Class, Aircraft_Type, Departure_Time, Departure_Port, Arrival_Time, Arrival_Port, Duration, Stop, Fare, Enjoy Free Meals]
# Index: []

# %%
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27465 entries, 0 to 29604
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           27465 non-null  category
#  1   Airline_Code      27465 non-null  object
#  2   Flight_Number     27465 non-null  int64
#  3   Cabin_Class       27465 non-null  category
#  4   Aircraft_Type     27465 non-null  object
#  5   Departure_Time    27465 non-null  datetime64[ns]
#  6   Departure_Port    27465 non-null  object
#  7   Arrival_Time      27465 non-null  datetime64[ns]
#  8   Arrival_Port      27465 non-null  object
#  9   Duration          27465 non-null  timedelta64[ns]
#  10  Stop              27465 non-null  int8
#  11  Fare              27465 non-null  int64
#  12  Enjoy Free Meals  27465 non-null  category
# dtypes: category(3), datetime64[ns](2), int64(2), int8(1), object(4), timedelta64[ns](1)
# memory usage: 2.2+ MB

# %%
tempdf[tempdf['Arrival_Port'] == 'Ghaziabad']
# Out:
# Empty DataFrame
# Columns: [Airline, Airline_Code, Flight_Number, Cabin_Class, Aircraft_Type, Departure_Time, Departure_Port, Arrival_Time, Arrival_Port, Duration, Stop, Fare, Enjoy Free Meals]
# Index: []

# %%
temp_df = tempdf.copy()

# %%
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27385 entries, 0 to 29604
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           27385 non-null  category
#  1   Airline_Code      27385 non-null  object
#  2   Flight_Number     27385 non-null  int64
#  3   Cabin_Class       27385 non-null  category
#  4   Aircraft_Type     27385 non-null  object
#  5   Departure_Time    27385 non-null  datetime64[ns]
#  6   Departure_Port    27385 non-null  object
#  7   Arrival_Time      27385 non-null  datetime64[ns]
#  8   Arrival_Port      27385 non-null  object
#  9   Duration          27385 non-null  timedelta64[ns]
#  10  Stop              27385 non-null  int8
#  11  Fare              27385 non-null  int64
#  12  Enjoy Free Meals  27385 non-null  category
# dtypes: category(3), datetime64[ns](2), int64(2), int8(1), object(4), timedelta64[ns](1)
# memory usage: 2.2+ MB

# %%
# temp_df.to_csv('flights_dataset.csv',index=False)
tempdf[tempdf['Departure_Port'] == 'Ghaziabad']
# Out:
# Empty DataFrame
# Columns: [Airline, Airline_Code, Flight_Number, Cabin_Class, Aircraft_Type, Departure_Time, Departure_Port, Arrival_Time, Arrival_Port, Duration, Stop, Fare, Enjoy Free Meals]
# Index: []

# %%
dic = {
    'Guwahati':'AAI',
    'Visakhapatnam': 'AAI',
    'Thiruvananthapuram' :'Adani Group',
    'Ayodhya': 'AAI',
    'Chennai': 'AAI',
    'Bhubaneswar': 'AAI',
    'Hyderabad': 'GMR Group',
    'Tiruchirappalli':'AAI',
    'Kannur': 'Govt of Kerala, PPP',
    'Cochin': 'Govt of Kerala & Private)',
    'Mangalore': 'Adani Group',
    'Imphal': 'AAI',
    'Indore': 'AAI',
    'Nagpur': 'MIHAN India Ltd (PPP)',
    'Lucknow': 'Adani Group',
    'Coimbatore': 'AAI',
    'Pune':'AAI (Military Civil Enclave)',
    'Surat': 'AAI',
    'Madurai': 'AAI',
    'Delhi': 'GMR Group',
    'Ahmedabad': 'Adani Group',
    'Bhopal':'AAI',
    'Kozhikode': 'AAI',
    'Jaipur': 'Adani Group',
    'Amritsar': 'AAI',
    'Port Blair': 'AAI',
    'Srinagar': 'AAI (Military Civil Enclave)',
    'Nasik': 'Hindustan Aeronautics Ltd (Civil enclave)',
    'Goa': 'Indian Navy / AAI Civil Enclave',
    'Gaya':'AAI',
    'Raipur': 'AAI',
    'Bengaluru': 'Fairfax India Holdings (PPP)',
    'Agartala': 'AAI'
}

tempdf['Dep_Port_Owned_by'] = tempdf['Departure_Port'].apply(lambda x:dic[x])

# %%
tempdf['Arv_Port_Owned_by'] = tempdf['Arrival_Port'].apply(lambda x:dic[x])

# %%
tempdf.drop(columns=['Owned_by'],inplace = True)

# %%
tempdf.sample(5)
# Out:
#                  Airline Airline_Code  Flight_Number Cabin_Class  \
# 8094              IndiGo           6E           2434     ECONOMY
# 919               IndiGo           6E           6269     ECONOMY
# 26489             IndiGo           6E           6421     ECONOMY
# 37     Air India Express           IX           2737     ECONOMY
# 27090             IndiGo           6E           7712     ECONOMY
#
#        Aircraft_Type      Departure_Time   Departure_Port        Arrival_Time  \
# 8094     Airbus A321 2025-07-05 11:30:00            Delhi 2025-07-05 20:20:00
# 919      Airbus A321 2025-07-05 07:15:00        Bengaluru 2025-07-05 12:45:00
# 26489    Airbus A320 2025-07-05 11:35:00       Coimbatore 2025-07-05 16:00:00
# 37       Airbus A320 2025-07-05 05:15:00        Bengaluru 2025-07-05 21:25:00
# 27090  Alenia ATR 42 2025-07-05 16:45:00  Tiruchirappalli 2025-07-05 22:05:00
#
#              Arrival_Port        Duration  Stop   Fare Enjoy Free Meals  \
# ...

# %%
data = {
    'Guwahati': 'Lokpriya Gopinath Bordoloi International Airport',
    'Visakhapatnam': 'Visakhapatnam International Airport',
    'Thiruvananthapuram': 'Trivandrum International Airport',
    'Ayodhya': 'Maharishi Valmiki International Airport',
    'Chennai': 'Chennai International Airport',
    'Bhubaneswar': 'Biju Patnaik International Airport',
    'Hyderabad': 'Rajiv Gandhi International Airport',
    'Tiruchirappalli': 'Tiruchirappalli International Airport',
    'Kannur': 'Kannur International Airport',
    'Cochin': 'Cochin International Airport',
    'Mangalore': 'Mangalore International Airport',
    'Imphal': 'Imphal International Airport',
    'Indore': 'Devi Ahilya Bai Holkar Airport',
    'Nagpur': 'Dr. Babasaheb Ambedkar International Airport',
    'Lucknow': 'Chaudhary Charan Singh International Airport',
    'Coimbatore': 'Coimbatore International Airport',
    'Pune': 'Pune Airport',
    'Surat': 'Surat International Airport',
    'Madurai': 'Madurai International Airport',
    'Delhi': 'Indira Gandhi International Airport',
    'Ahmedabad': 'Sardar Vallabhbhai Patel International Airport',
    'Bhopal': 'Raja Bhoj International Airport',
    'Kozhikode': 'Calicut International Airport',
    'Jaipur': 'Jaipur International Airport',
    'Amritsar': 'Sri Guru Ram Dass Jee International Airport',
    'Port Blair': 'Veer Savarkar International Airport',
    'Srinagar': 'Sheikh ul-Alam International Airport',
    'Nasik': 'Nashik Airport (Ozar)',
    'Goa': 'Goa Dabolim Airport',
    'Gaya': 'Gaya International Airport',
    'Raipur': 'Swami Vivekananda Airport',
    'Bengaluru': 'Kempegowda International Airport',
    'Agartala': 'Maharaja Bir Bikram Airport'
    }

# %%
tempdf['Dep_Port_Name'] = tempdf['Departure_Port'].apply(lambda x:data[x])
tempdf['Arv_Port_Name'] = tempdf['Arrival_Port'].apply(lambda x:data[x])

# %%
tempdf.sample(5)
# Out:
#                  Airline Airline_Code  Flight_Number Cabin_Class  \
# 12855          Air India           AI           9553     ECONOMY
# 24511             IndiGo           6E           7417     ECONOMY
# 16861             IndiGo           6E           7049     ECONOMY
# 26165  Air India Express           IX           1171     ECONOMY
# 12887          Air India           AI           2983     ECONOMY
#
#        Aircraft_Type      Departure_Time Departure_Port        Arrival_Time  \
# 12855     Boeing 737 2025-07-05 23:30:00           Pune 2025-07-05 08:10:00
# 24511  Alenia ATR 42 2025-07-05 10:50:00      Hyderabad 2025-07-05 18:00:00
# 16861  Alenia ATR 42 2025-07-05 12:50:00         Kannur 2025-07-05 21:20:00
# 26165     Boeing 737 2025-07-05 16:45:00          Surat 2025-07-05 12:45:00
# 12887    Airbus A320 2025-07-05 15:55:00           Pune 2025-07-05 23:25:00
#
#       Arrival_Port        Duration  Stop   Fare Enjoy Free Meals  \
# ...

# %%
temp_df = tempdf.iloc[:,:]

# %%
dis
# Out:
#      From   To  Distance_km
# 0     BLR  DEL      1733.68
# 1     BLR  GOI       486.13
# 2     BLR  AYJ      1612.19
# 3     BLR  ISK       875.93
# 4     BLR  COK       339.38
# ...   ...  ...          ...
# 1051  CCJ  IXE       233.72
# 1052  CCJ  CNN        97.31
# 1053  CCJ  MAA       502.79
# 1054  CCJ  PNQ       856.35
# 1055  CCJ  AMD      1373.29
#
# [1056 rows x 3 columns]

# %%
airport_dict = {
    'BLR': 'Bengaluru',
    'DEL': 'Delhi',
    'GOI': 'Goa',
    'AYJ': 'Ayodhya',
    'ISK': 'Nashik',
    'COK': 'Kochi',
    'GAY': 'Gaya',
    'BHO': 'Bhopal',
    'ATQ': 'Amritsar',
    'NAG': 'Nagpur',
    'SXR': 'Srinagar',
    'TRV': 'Thiruvananthapuram',
    'IXM': 'Madurai',
    'TRZ': 'Tiruchirappalli',
    'CJB': 'Coimbatore',
    'STV': 'Surat',
    'HYD': 'Hyderabad',
    'VTZ': 'Visakhapatnam',
    'RPR': 'Raipur',
    'IXA': 'Agartala',
    'IXZ': 'Port Blair',
    'IDR': 'Indore',
    'BBI': 'Bhubaneswar',
    'JAI': 'Jaipur',
    'GAU': 'Guwahati',
    'IMF': 'Imphal',
    'LKO': 'Lucknow',
    'IXE': 'Mangaluru',
    'CNN': 'Kannur',
    'MAA': 'Chennai',
    'PNQ': 'Pune',
    'AMD': 'Ahmedabad',
    'CCJ': 'Kozhikode'
}

dis.replace(airport_dict,inplace=True)

# %%
temp_df = pd.read_csv('/content/flights_dataset (1).csv')

# %%
temp_df.drop(columns=['Unnamed: 0'],inplace = True)

# %%
temp_df.sample(2)
# Out:
#          Airline Airline_Code  Flight_Number Cabin_Class Aircraft_Type  \
# 13779  Air India           AI           9668    BUSINESS    Boeing 737
# 22306  Air India           AI           2880     ECONOMY    Airbus 32N
#
#          Departure_Time Departure_Port      Arrival_Time        Arrival_Port  \
# 13779  05-07-2025 15:30      Mangalore  05-07-2025 16:05              Cochin
# 22306  05-07-2025 18:15      Hyderabad  05-07-2025 02:15  Thiruvananthapuram
#
#               Duration  Stop   Fare Enjoy Free Meals Dep_Port_Owned_by  \
# 13779  1 days 00:35:00     1  40539              Yes       Adani Group
# 22306  0 days 08:00:00     1  12394              Yes         GMR Group
#
#                Arv_Port_Owned_by                       Dep_Port_Name  \
# 13779  Govt of Kerala & Private)     Mangalore International Airport
# 22306                Adani Group  Rajiv Gandhi International Airport
#
#                           Arv_Port_Name
# 13779      Cochin International Airport
# ...

# %%
temp_df['Airline'] = temp_df['Airline'].astype('category')

# %%
temp_df['Flight_Number'] = temp_df['Flight_Number'].astype('int32')

# %%
temp_df['Cabin_Class'] = temp_df['Cabin_Class'].astype('category')

# %%
temp_df['Airline_Code'] = temp_df.Airline_Code.astype('category')

# %%
temp_df['Departure_Time'] = pd.to_datetime(temp_df['Departure_Time']).dt.time

# %%
temp_df['Arrival_Time'] = pd.to_datetime(temp_df['Arrival_Time']).dt.time

# %%
temp_df['Duration'] = temp_df['Duration'].astype('object')

# %%
# tempdf['Duration'] = tempdf['Duration'].apply(lambda x:(pd.Timestamp("00:00:00") + x).time())

temp_df['Duration'] = temp_df['Duration'].astype('str').apply(lambda x:x.split(' ')[-1])

# %%
temp_df['Enjoy Free Meals'] = temp_df['Enjoy Free Meals'].astype('category')

# %%
temp_df['Dep_Port_Owned_by'].value_counts()

# %%
temp_df['Dep_Port_Name'].value_counts()

# %%
temp_df['Departure_Port'].value_counts()

# %%
temp_df.sample(2)
# Out:
#          Airline Airline_Code  Flight_Number Cabin_Class Aircraft_Type  \
# 22071  Air India           AI           2872    BUSINESS    Airbus 32N
# 2768   Air India           AI            434    BUSINESS   Airbus A320
#
#       Departure_Time Departure_Port Arrival_Time Arrival_Port  Duration  Stop  \
# 22071       06:15:00      Hyderabad     12:05:00       Bhopal  05:50:00     1
# 2768        16:25:00         Bhopal     10:15:00   Port Blair  17:50:00     1
#
#         Fare Enjoy Free Meals Dep_Port_Owned_by Arv_Port_Owned_by  \
# 22071  25794              Yes         GMR Group               AAI
# 2768   62771              Yes               AAI               AAI
#
#                             Dep_Port_Name                        Arv_Port_Name
# 22071  Rajiv Gandhi International Airport      Raja Bhoj International Airport
# 2768      Raja Bhoj International Airport  Veer Savarkar International Airport

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27385 entries, 0 to 27384
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            27385 non-null  category
#  1   Airline_Code       27385 non-null  category
#  2   Flight_Number      27385 non-null  int32
#  3   Cabin_Class        27385 non-null  category
#  4   Aircraft_Type      27385 non-null  object
#  5   Departure_Time     27385 non-null  object
#  6   Departure_Port     27385 non-null  object
#  7   Arrival_Time       27385 non-null  object
#  8   Arrival_Port       27385 non-null  object
#  9   Duration           27385 non-null  object
#  10  Stop               27385 non-null  int64
#  11  Fare               27385 non-null  int64
#  12  Enjoy Free Meals   27385 non-null  category
#  13  Dep_Port_Owned_by  27385 non-null  object
#  14  Arv_Port_Owned_by  27385 non-null  object
#  15  Dep_Port_Name      27385 non-null  object
# ...

# %%
temp_df['Departure_Time'].apply(lambda x:x.hour)

# %%
temp_df.to_csv('flight_dataset.csv',index=False)
